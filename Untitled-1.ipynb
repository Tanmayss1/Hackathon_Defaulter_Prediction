# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("train_loan_data (1).csv")
df.head()
# Out:
#   addr_state  annual_inc earliest_cr_line emp_length  \
# 0         CO     85000.0           Jul-97  10+ years
# 1         CA     40000.0           Apr-87  10+ years
# 2         FL     60000.0           Aug-07  10+ years
# 3         IL    100742.0           Sep-80  10+ years
# 4         MD     80000.0           Jul-99  10+ years
#
#                         emp_title  fico_range_high  fico_range_low grade  \
# 0                          Deputy              744             740     E
# 1  Department of Veterans Affairs              724             720     B
# 2                Marble polishing              679             675     B
# 3                         printer              664             660     B
# 4                   Southern Mgmt              669             665     F
#
#   home_ownership application_type  ... pub_rec_bankruptcies  \
# 0       MORTGAGE       Individual  ...                  0.0
# 1           RENT       Individual  ...                  0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80000 entries, 0 to 79999
# Data columns (total 28 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   addr_state            80000 non-null  object
#  1   annual_inc            80000 non-null  float64
#  2   earliest_cr_line      80000 non-null  object
#  3   emp_length            75412 non-null  object
#  4   emp_title             74982 non-null  object
#  5   fico_range_high       80000 non-null  int64
#  6   fico_range_low        80000 non-null  int64
#  7   grade                 80000 non-null  object
#  8   home_ownership        80000 non-null  object
#  9   application_type      80000 non-null  object
#  10  initial_list_status   80000 non-null  object
#  11  int_rate              80000 non-null  float64
#  12  loan_amnt             80000 non-null  int64
#  13  num_actv_bc_tl        76052 non-null  float64
#  14  mort_acc              77229 non-null  float64
# ...

# %%
df.describe()
# Out:
#          annual_inc  fico_range_high  fico_range_low      int_rate  \
# count  8.000000e+04     80000.000000    80000.000000  80000.000000
# mean   7.604614e+04       699.987975      695.987813     13.232898
# std    6.902006e+04        31.734840       31.734075      4.771705
# min    0.000000e+00       664.000000      660.000000      5.310000
# 25%    4.600000e+04       674.000000      670.000000      9.750000
# 50%    6.500000e+04       694.000000      690.000000     12.740000
# 75%    9.000000e+04       714.000000      710.000000     15.990000
# max    7.141778e+06       850.000000      845.000000     30.990000
#
#           loan_amnt  num_actv_bc_tl      mort_acc   tot_cur_bal      open_acc  \
# count  80000.000000    76052.000000  77229.000000  7.605200e+04  80000.000000
# mean   14403.867813        3.633790      1.674759  1.415864e+05     11.605675
# std     8703.826298        2.262505      2.005104  1.593714e+05      5.483362
# ...

# %%
# Checking Null values
df.isnull().sum()
# Out:
# addr_state                 0
# annual_inc                 0
# earliest_cr_line           0
# emp_length              4588
# emp_title               5018
# fico_range_high            0
# fico_range_low             0
# grade                      0
# home_ownership             0
# application_type           0
# initial_list_status        0
# int_rate                   0
# loan_amnt                  0
# num_actv_bc_tl          3948
# mort_acc                2771
# tot_cur_bal             3948
# open_acc                   0
# pub_rec                    0
# pub_rec_bankruptcies      31
# purpose                    0
# revol_bal                  0
# revol_util                53
# sub_grade                  0
# term                       0
# title                    970
# total_acc                  0
# verification_status        0
# loan_status                0
# dtype: int64

# %%
plt.figure(figsize=(18, 12))

plt.subplot(2, 3, 1)

df['loan_status'].value_counts().plot(kind='bar')
plt.title('Loan Status Distribution')
plt.xlabel('Loan Status')
plt.ylabel('Count')

plt.subplot(2, 3, 2)

sns.boxplot(x='loan_status', y='loan_amnt', data=df)
plt.title('Loan Amount vs. Loan Status')
plt.xlabel('Loan Status')
plt.ylabel('Loan Amount')


plt.subplot(2, 3, 3)

sns.boxplot(x='loan_status', y='int_rate', data=df)
plt.title('Interest Rate vs. Loan Status')
plt.xlabel('Loan Status')
plt.ylabel('Interest Rate')


plt.subplot(2, 3, 4)

sns.violinplot(x='loan_status', y='annual_inc', data=df)
plt.title('Income Distribution by Loan Status')
plt.xlabel('Loan Status')
plt.ylabel('Annual Income')


plt.subplot(2, 3, 5)

sns.countplot(x='purpose', hue='loan_status', data=df)
plt.title('Loan Purpose vs. Loan Status')
plt.xlabel('Loan Purpose')
plt.ylabel('Count')
plt.xticks(rotation=90)

plt.subplot(2, 3, 6)

sns.countplot(x='emp_length', hue='loan_status', data=df)
plt.title('Employment Length vs. Loan Status')
plt.xlabel('Employment Length')
plt.ylabel('Count')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
loan_status_counts = df['loan_status'].value_counts()
print("Loan Status Distribution:")
print(loan_status_counts)
# Out:
# Loan Status Distribution:
# loan_status
# Paid         64030
# Defaulted    15970
# Name: count, dtype: int64

# %%
loan_purpose_vs_status = pd.crosstab(df['purpose'], df['loan_status'])
print("Loan Purpose vs. Loan Status:")
print(loan_purpose_vs_status)
# Out:
# Loan Purpose vs. Loan Status:
# loan_status         Defaulted   Paid
# purpose
# car                       134    734
# credit_card              2972  14534
# debt_consolidation       9709  36709
# educational                 3     13
# home_improvement         1001   4267
# house                      99    314
# major_purchase            325   1421
# medical                   176    726
# moving                    130    418
# other                     991   3692
# renewable_energy           16     38
# small_business            297    653
# vacation                  105    413
# wedding                    12     98

# %%
emp_length_vs_status = pd.crosstab(df['emp_length'], df['loan_status'])
print("Employment Length vs. Loan Status:")
print(emp_length_vs_status)
# Out:
# Employment Length vs. Loan Status:
# loan_status  Defaulted   Paid
# emp_length
# 1 year            1050   4244
# 10+ years         4963  21315
# 2 years           1467   5852
# 3 years           1262   5212
# 4 years            948   3815
# 5 years            999   4095
# 6 years            722   2969
# 7 years            748   2849
# 8 years            715   2868
# 9 years            606   2416
# < 1 year          1251   5046

# %% [markdown]
# # Summary
#
# ### Loan Status Distribution:
#
# Total loans: 80,000
# Paid loans: 64,030 (80.04%)
# Defaulted loans: 15,970 (19.96%)
#
# ### Loan Purpose vs. Loan Status:
#
# "Debt Consolidation" is the most common loan purpose for both paid and defaulted loans.
# "Car" and "Educational" purposes have a significantly higher percentage of defaulted loans compared to paid loans.
# "Credit Card," "Home Improvement," and "Major Purchase" purposes have a higher percentage of paid loans compared to defaulted loans.
#
# ### Employment Length vs. Loan Status:
#
# Borrowers with "10+ years" of employment history have the highest number of both paid and defaulted loans.
# Borrowers with "< 1 year" of employment history have a relatively high percentage of defaulted loans compared to paid loans.
# Employment length does not show a strong pattern in the data, as the distribution of defaulted and paid loans is relatively consistent across different employment lengths.
#
#
# ### Overall, the majority of loans are paid, but there are variations in loan purposes and employment lengths that may impact the likelihood of default. These insights can help in understanding the factors that contribute to loan status and guide further analysis and modeling.

# %% [markdown]
# ### Coming back on missing values

# %%
df.isnull().sum()
# Out:
# addr_state                 0
# annual_inc                 0
# earliest_cr_line           0
# emp_length              4588
# emp_title               5018
# fico_range_high            0
# fico_range_low             0
# grade                      0
# home_ownership             0
# application_type           0
# initial_list_status        0
# int_rate                   0
# loan_amnt                  0
# num_actv_bc_tl          3948
# mort_acc                2771
# tot_cur_bal             3948
# open_acc                   0
# pub_rec                    0
# pub_rec_bankruptcies      31
# purpose                    0
# revol_bal                  0
# revol_util                53
# sub_grade                  0
# term                       0
# title                    970
# total_acc                  0
# verification_status        0
# loan_status                0
# dtype: int64

# %%
#filling with mode values: as these are categorical values
mode_emp_length = df['emp_length'].mode().iloc[0]
mode_emp_title = df['emp_title'].mode().iloc[0]

#filling with median values: as these are numerical values
median_num_actv_bc_tl = df['num_actv_bc_tl'].median()
median_mort_acc = df['mort_acc'].median()
median_tot_cur_bal = df['tot_cur_bal'].median()

# %%
df['emp_length'].fillna(mode_emp_length, inplace=True)
df['emp_title'].fillna(mode_emp_length, inplace=True)

df['num_actv_bc_tl'].fillna(mean_num_actv_bc_tl, inplace=True)
df['mort_acc'].fillna(median_mort_acc, inplace=True)
df['tot_cur_bal'].fillna(mean_tot_cur_bal, inplace=True)

# %%
#revmoivng these columns with fewer null values
df.dropna(subset=['pub_rec_bankruptcies'], inplace=True)
df.dropna(subset=['revol_util'], inplace=True)
df.dropna(subset=['title'], inplace=True)

# %%
df.isnull().sum()
# Out:
# addr_state              0
# annual_inc              0
# earliest_cr_line        0
# emp_length              0
# emp_title               0
# fico_range_high         0
# fico_range_low          0
# grade                   0
# home_ownership          0
# application_type        0
# initial_list_status     0
# int_rate                0
# loan_amnt               0
# num_actv_bc_tl          0
# mort_acc                0
# tot_cur_bal             0
# open_acc                0
# pub_rec                 0
# pub_rec_bankruptcies    0
# purpose                 0
# revol_bal               0
# revol_util              0
# sub_grade               0
# term                    0
# title                   0
# total_acc               0
# verification_status     0
# loan_status             0
# ZScore                  0
# addr_state_encoded      0
# dtype: int64

# %% [markdown]
# ### Now as our dataset is cleaned now in terms of null values, lets check the outliers and try working on them

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 78947 entries, 0 to 79999
# Data columns (total 30 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   addr_state            78947 non-null  object
#  1   annual_inc            78947 non-null  float64
#  2   earliest_cr_line      78947 non-null  object
#  3   emp_length            78947 non-null  object
#  4   emp_title             78947 non-null  object
#  5   fico_range_high       78947 non-null  int64
#  6   fico_range_low        78947 non-null  int64
#  7   grade                 78947 non-null  object
#  8   home_ownership        78947 non-null  object
#  9   application_type      78947 non-null  object
#  10  initial_list_status   78947 non-null  object
#  11  int_rate              78947 non-null  float64
#  12  loan_amnt             78947 non-null  int64
#  13  num_actv_bc_tl        78947 non-null  float64
#  14  mort_acc              78947 non-null  float64
# ...

# %%
categorical_columns = df.select_dtypes(include=['object']).columns
numerical_columns = df.select_dtypes(include=['int64','float64']).columns

categorical_df = df[categorical_columns]
numerical_df = df[numerical_columns]

# %%
numerical_columns
# Out:
# ['annual_inc',
#  'fico_range_high',
#  'fico_range_low',
#  'int_rate',
#  'loan_amnt',
#  'num_actv_bc_tl',
#  'mort_acc',
#  'tot_cur_bal',
#  'open_acc',
#  'pub_rec',
#  'pub_rec_bankruptcies',
#  'revol_bal',
#  'revol_util',
#  'total_acc']

# %%
# Creating subplots for the numerical columns
fig, axes = plt.subplots(nrows=5, ncols=3, figsize=(16, 12))
fig.subplots_adjust(hspace=1.0)

for i, column in enumerate(numerical_columns):
    row = i // 3
    col = i % 3
    ax = axes[row, col]
    
    # Create a box plot for the current column
    sns.boxplot(x=df[column], ax=ax)
    ax.set_title(f'Box Plot of {column}')
    ax.set_ylabel(column)

# Show the subplots
plt.show()

# %% [markdown]
# #### So from above plots we can say that, each of the numerical columns has outliers present in it, so we have multiple options with us, wheather to impute the values with median or do the rest featuring steps.
# #### But before that we need to transform the categorical values as well

# %%
categorical_columns
# Out:
# Index(['addr_state', 'earliest_cr_line', 'emp_length', 'emp_title', 'grade',
#        'home_ownership', 'application_type', 'initial_list_status', 'purpose',
#        'sub_grade', 'term', 'title', 'verification_status', 'loan_status'],
#       dtype='object')

# %%
addr_state_column_numbers = df['addr_state'].nunique()
print(addr_state_column_numbers)
# Out:
# 50

# %%
df['grade'].value_counts()
# Out:
# grade
# B    23183
# C    22221
# A    13852
# D    11775
# E     5545
# F     1844
# G      527
# Name: count, dtype: int64

# %%
df['home_ownership'].value_counts()
# Out:
# home_ownership
# MORTGAGE    39155
# RENT        31226
# OWN          8537
# ANY            19
# OTHER           6
# NONE            4
# Name: count, dtype: int64

# %%
columns_to_check = ['earliest_cr_line', 'emp_length', 'emp_title', 'grade',
                     'home_ownership', 'application_type', 'initial_list_status', 'purpose',
                     'sub_grade', 'term', 'title', 'verification_status', 'loan_status']

for column in columns_to_check:
    unique_categories = df[column].nunique()
    print(f"Number of unique categories in '{column}': {unique_categories}")
# Out:
# Number of unique categories in 'earliest_cr_line': 639
# Number of unique categories in 'emp_length': 11
# Number of unique categories in 'emp_title': 36316
# Number of unique categories in 'grade': 7
# Number of unique categories in 'home_ownership': 6
# Number of unique categories in 'application_type': 2
# Number of unique categories in 'initial_list_status': 2
# Number of unique categories in 'purpose': 14
# Number of unique categories in 'sub_grade': 35
# Number of unique categories in 'term': 2
# Number of unique categories in 'title': 5320
# Number of unique categories in 'verification_status': 3
# Number of unique categories in 'loan_status': 2
